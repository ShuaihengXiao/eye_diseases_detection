# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144793 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import numpy as np
from keras.utils import np_utils
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
import tqdm
import os
import cv2

# %%
file = h5py.File('/content/drive/My Drive/aug_dataset.hdf5',mode = 'r')

# %%
N_dataset_x_train = file['N_dataset_x_train'][:700]
N_dataset_y_train = file['N_dataset_y_train'][:700]
N_dataset_x_val = file['N_dataset_x_val'][:200]
N_dataset_y_val = file['N_dataset_y_val'][:200]
N_dataset_x_test = file['N_dataset_x_test'][:100]
N_dataset_y_test = file['N_dataset_y_test'][:100]

# %%
D_dataset_x_train = file['D_dataset_x_train'][:700]
D_dataset_y_train = file['D_dataset_y_train'][:700]
D_dataset_x_val = file['D_dataset_x_val'][:200]
D_dataset_y_val = file['D_dataset_y_val'][:200]
D_dataset_x_test = file['D_dataset_x_test'][:100]
D_dataset_y_test = file['D_dataset_y_test'][:100]

# %%
G_dataset_x_train = file['G_dataset_x_train'][:700]
G_dataset_y_train = file['G_dataset_y_train'][:700]
G_dataset_x_val = file['G_dataset_x_val'][:200]
G_dataset_y_val = file['G_dataset_y_val'][:200]
G_dataset_x_test = file['G_dataset_x_test'][:100]
G_dataset_y_test = file['G_dataset_y_test'][:100]

# %%
C_dataset_x_train = file['C_dataset_x_train'][:700]
C_dataset_y_train = file['C_dataset_y_train'][:700]
C_dataset_x_val = file['C_dataset_x_val'][:200]
C_dataset_y_val = file['C_dataset_y_val'][:200]
C_dataset_x_test = file['C_dataset_x_test'][:100]
C_dataset_y_test = file['C_dataset_y_test'][:100]

# %%
A_dataset_x_train = file['A_dataset_x_train'][:700]
A_dataset_y_train = file['A_dataset_y_train'][:700]
A_dataset_x_val = file['A_dataset_x_val'][:200]
A_dataset_y_val = file['A_dataset_y_val'][:200]
A_dataset_x_test = file['A_dataset_x_test'][:100]
A_dataset_y_test = file['A_dataset_y_test'][:100]

# %%
M_dataset_x_train = file['M_dataset_x_train'][:700]
M_dataset_y_train = file['M_dataset_y_train'][:700]
M_dataset_x_val = file['M_dataset_x_val'][:200]
M_dataset_y_val = file['M_dataset_y_val'][:200]
M_dataset_x_test = file['M_dataset_x_test'][:100]
M_dataset_y_test = file['M_dataset_y_test'][:100]

# %%
H_dataset_x_train = file['H_dataset_x_train'][:]
H_dataset_y_train = file['H_dataset_y_train'][:]
H_dataset_x_val = file['H_dataset_x_val'][:]
H_dataset_y_val = file['H_dataset_y_val'][:]
H_dataset_x_test = file['H_dataset_x_test'][:]
H_dataset_y_test = file['H_dataset_y_test'][:]

# %%
for i in range(len(H_dataset_y_train)):
    H_dataset_y_train[i] = 1
for i in range(len(H_dataset_y_val)):
    H_dataset_y_val[i] = 1
for i in range(len(H_dataset_y_test)):
    H_dataset_y_test[i] = 1

for i in range(len(N_dataset_y_train)):
    N_dataset_y_train[i] = 0
for i in range(len(N_dataset_y_val)):
    N_dataset_y_val[i] = 0
for i in range(len(N_dataset_y_test)):
    N_dataset_y_test[i] = 0

for i in range(len(D_dataset_y_train)):
    D_dataset_y_train[i] = 0
for i in range(len(D_dataset_y_val)):
    D_dataset_y_val[i] = 0
for i in range(len(D_dataset_y_test)):
    D_dataset_y_test[i] = 0

for i in range(len(G_dataset_y_train)):
    G_dataset_y_train[i] = 0
for i in range(len(G_dataset_y_val)):
    G_dataset_y_val[i] = 0
for i in range(len(G_dataset_y_test)):
    G_dataset_y_test[i] = 0
for i in range(len(C_dataset_y_train)):
    C_dataset_y_train[i] = 0
for i in range(len(C_dataset_y_val)):
    C_dataset_y_val[i] = 0
for i in range(len(C_dataset_y_test)):
    C_dataset_y_test[i] = 0
for i in range(len(A_dataset_y_train)):
    A_dataset_y_train[i] = 0
for i in range(len(A_dataset_y_val)):
    A_dataset_y_val[i] = 0
for i in range(len(A_dataset_y_test)):
    A_dataset_y_test[i] = 0
for i in range(len(M_dataset_y_train)):
    M_dataset_y_train[i] = 0
for i in range(len(M_dataset_y_val)):
    M_dataset_y_val[i] = 0
for i in range(len(M_dataset_y_test)):
    M_dataset_y_test[i] = 0

# %%
y_train = np.concatenate(( N_dataset_y_train,D_dataset_y_train,G_dataset_y_train,C_dataset_y_train,H_dataset_y_train,M_dataset_y_train,A_dataset_y_train))
y_val = np.concatenate((N_dataset_y_val,D_dataset_y_val,G_dataset_y_val,C_dataset_y_val,H_dataset_y_val,M_dataset_y_val,A_dataset_y_val))
y_test = np.concatenate((N_dataset_y_test,D_dataset_y_test,G_dataset_y_test,C_dataset_y_test,H_dataset_y_test,M_dataset_y_test,A_dataset_y_test))

# %%
x_train = np.concatenate(( N_dataset_x_train,D_dataset_x_train,G_dataset_x_train,C_dataset_x_train,H_dataset_x_train,M_dataset_x_train,A_dataset_x_train))
x_val = np.concatenate((N_dataset_x_val,D_dataset_x_val,G_dataset_x_val,C_dataset_x_val,H_dataset_x_val,M_dataset_x_val,A_dataset_x_val))
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,H_dataset_x_test,M_dataset_x_test,A_dataset_x_test))

# %%
del N_dataset_x_train
del N_dataset_y_train
del N_dataset_x_val
del N_dataset_y_val
del N_dataset_x_test
del N_dataset_y_test
del A_dataset_x_train
del A_dataset_y_train
del A_dataset_x_val
del A_dataset_y_val
del A_dataset_x_test
del A_dataset_y_test
del D_dataset_x_train
del D_dataset_y_train
del D_dataset_x_val
del D_dataset_y_val
del D_dataset_x_test
del D_dataset_y_test
del G_dataset_x_train
del G_dataset_y_train
del G_dataset_x_val
del G_dataset_y_val
del G_dataset_x_test
del G_dataset_y_test
del C_dataset_x_train
del C_dataset_y_train
del C_dataset_x_val
del C_dataset_y_val
del C_dataset_x_test
del C_dataset_y_test
del H_dataset_x_train
del H_dataset_y_train
del H_dataset_x_val
del H_dataset_y_val
del H_dataset_x_test
del H_dataset_y_test
del M_dataset_x_train
del M_dataset_y_train
del M_dataset_x_val
del M_dataset_y_val
del M_dataset_x_test
del M_dataset_y_test

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')


x_train/=255
x_val/=255
x_test /= 255

# %%
vgg = VGG19(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
checkpoint = ModelCheckpoint("/content/drive/My Drive/weights_weights_NH.h5",monitor="val_accuracy",verbose=1,save_best_only=True,
                             save_weights_only=True)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,verbose=1)

# %%
history = model.fit(x_train,y_train, batch_size = 32, epochs = 100, validation_data=(x_val,y_val),shuffle = True,verbose=1,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/100
# 158/158 [==============================] - ETA: 0s - loss: 0.3730 - accuracy: 0.8533
# Epoch 00001: val_accuracy improved from -inf to 0.88652, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 31s 194ms/step - loss: 0.3730 - accuracy: 0.8533 - val_loss: 0.2765 - val_accuracy: 0.8865
# Epoch 2/100
# 158/158 [==============================] - ETA: 0s - loss: 0.2451 - accuracy: 0.9002
# Epoch 00002: val_accuracy improved from 0.88652 to 0.88936, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 30s 190ms/step - loss: 0.2451 - accuracy: 0.9002 - val_loss: 0.2720 - val_accuracy: 0.8894
# Epoch 3/100
# 158/158 [==============================] - ETA: 0s - loss: 0.1778 - accuracy: 0.9315
# Epoch 00003: val_accuracy improved from 0.88936 to 0.92482, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 32s 204ms/step - loss: 0.1778 - accuracy: 0.9315 - val_loss: 0.2061 - val_accuracy: 0.9248
# Epoch 4/100
# 158/158 [==============================] - ETA: 0s - loss: 0.1578 - accuracy: 0.9418
# Epoch 00004: val_accuracy improved from 0.92482 to 0.93546, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 211ms/step - loss: 0.1578 - accuracy: 0.9418 - val_loss: 0.1815 - val_accuracy: 0.9355
# Epoch 5/100
# 158/158 [==============================] - ETA: 0s - loss: 0.1215 - accuracy: 0.9611
# Epoch 00005: val_accuracy did not improve from 0.93546
# 158/158 [==============================] - 32s 202ms/step - loss: 0.1215 - accuracy: 0.9611 - val_loss: 0.1713 - val_accuracy: 0.9348
# Epoch 6/100
# 158/158 [==============================] - ETA: 0s - loss: 0.1093 - accuracy: 0.9655
# Epoch 00006: val_accuracy did not improve from 0.93546
# 158/158 [==============================] - 32s 205ms/step - loss: 0.1093 - accuracy: 0.9655 - val_loss: 0.1684 - val_accuracy: 0.9348
# Epoch 7/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0904 - accuracy: 0.9732
# Epoch 00007: val_accuracy did not improve from 0.93546
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0904 - accuracy: 0.9732 - val_loss: 0.1881 - val_accuracy: 0.9234
# Epoch 8/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0784 - accuracy: 0.9796
# Epoch 00008: val_accuracy improved from 0.93546 to 0.94681, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 210ms/step - loss: 0.0784 - accuracy: 0.9796 - val_loss: 0.1423 - val_accuracy: 0.9468
# Epoch 9/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9843
# Epoch 00009: val_accuracy improved from 0.94681 to 0.95106, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 209ms/step - loss: 0.0690 - accuracy: 0.9843 - val_loss: 0.1502 - val_accuracy: 0.9511
# Epoch 10/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0576 - accuracy: 0.9889
# Epoch 00010: val_accuracy improved from 0.95106 to 0.95461, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 210ms/step - loss: 0.0576 - accuracy: 0.9889 - val_loss: 0.1403 - val_accuracy: 0.9546
# Epoch 11/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0524 - accuracy: 0.9913
# Epoch 00011: val_accuracy did not improve from 0.95461
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0524 - accuracy: 0.9913 - val_loss: 0.1299 - val_accuracy: 0.9525
# Epoch 12/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0508 - accuracy: 0.9905
# Epoch 00012: val_accuracy improved from 0.95461 to 0.95532, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 210ms/step - loss: 0.0508 - accuracy: 0.9905 - val_loss: 0.1344 - val_accuracy: 0.9553
# Epoch 13/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9954
# Epoch 00013: val_accuracy did not improve from 0.95532
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0403 - accuracy: 0.9954 - val_loss: 0.1250 - val_accuracy: 0.9504
# Epoch 14/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0365 - accuracy: 0.9962
# Epoch 00014: val_accuracy improved from 0.95532 to 0.96028, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 208ms/step - loss: 0.0365 - accuracy: 0.9962 - val_loss: 0.1153 - val_accuracy: 0.9603
# Epoch 15/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9960
# Epoch 00015: val_accuracy did not improve from 0.96028
# 158/158 [==============================] - 32s 206ms/step - loss: 0.0345 - accuracy: 0.9960 - val_loss: 0.1277 - val_accuracy: 0.9567
# Epoch 16/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0300 - accuracy: 0.9972
# Epoch 00016: val_accuracy did not improve from 0.96028
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0300 - accuracy: 0.9972 - val_loss: 0.1181 - val_accuracy: 0.9603
# Epoch 17/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9986
# Epoch 00017: val_accuracy improved from 0.96028 to 0.96170, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 209ms/step - loss: 0.0264 - accuracy: 0.9986 - val_loss: 0.1145 - val_accuracy: 0.9617
# Epoch 18/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0227 - accuracy: 0.9992
# Epoch 00018: val_accuracy did not improve from 0.96170
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0227 - accuracy: 0.9992 - val_loss: 0.1270 - val_accuracy: 0.9610
# Epoch 19/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9992
# Epoch 00019: val_accuracy improved from 0.96170 to 0.96383, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 208ms/step - loss: 0.0207 - accuracy: 0.9992 - val_loss: 0.1080 - val_accuracy: 0.9638
# Epoch 20/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9996
# Epoch 00020: val_accuracy did not improve from 0.96383
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0188 - accuracy: 0.9996 - val_loss: 0.1064 - val_accuracy: 0.9617
# Epoch 21/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9998
# Epoch 00021: val_accuracy did not improve from 0.96383
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0168 - accuracy: 0.9998 - val_loss: 0.1084 - val_accuracy: 0.9631
# Epoch 22/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9998
# Epoch 00022: val_accuracy improved from 0.96383 to 0.96596, saving model to /content/drive/My Drive/weights_weights_NH.h5
# 158/158 [==============================] - 33s 210ms/step - loss: 0.0157 - accuracy: 0.9998 - val_loss: 0.1079 - val_accuracy: 0.9660
# Epoch 23/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 1.0000
# Epoch 00023: val_accuracy did not improve from 0.96596
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9645
# Epoch 24/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 1.0000
# Epoch 00024: val_accuracy did not improve from 0.96596
# 158/158 [==============================] - 32s 203ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.1190 - val_accuracy: 0.9610
# Epoch 25/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.96596
# 158/158 [==============================] - 32s 206ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.1060 - val_accuracy: 0.9638
# Epoch 26/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0106 - accuracy: 1.0000
# Epoch 00026: val_accuracy did not improve from 0.96596
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.1293 - val_accuracy: 0.9652
# Epoch 27/100
# 158/158 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 1.0000
# Epoch 00027: val_accuracy did not improve from 0.96596
# 158/158 [==============================] - 32s 205ms/step - loss: 0.0102 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9660
# Epoch 00027: early stopping

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
fig = plt.figure(figsize=(12,6))
epochs = range(1,len(history.history['accuracy'])+1)
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"go-")
plt.plot(epochs,history.history["val_accuracy"],"ro-")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train","val"],loc = "upper left")

plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"go-")
plt.plot(epochs,history.history["val_loss"],"ro-")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train","val"],loc = "upper left")
plt.show()

# %%
model.load_weights('/content/drive/My Drive/weights_weights_NH.h5')

# %%
model.evaluate(x_test,y_test)
# Out:
# 23/23 [==============================] - 3s 150ms/step - loss: 0.1376 - accuracy: 0.9623
# [0.13756407797336578, 0.9623430967330933]

# %% [markdown]
# predict different class

# %%
N_dataset_x_test = file['N_dataset_x_test'][:]
N_dataset_x_test = N_dataset_x_test[:100]
D_dataset_x_test = file['D_dataset_x_test'][:]
D_dataset_x_test = D_dataset_x_test[:100]
G_dataset_x_test = file['G_dataset_x_test'][:]
G_dataset_x_test = G_dataset_x_test[:100]
C_dataset_x_test = file['C_dataset_x_test'][:]
C_dataset_x_test = C_dataset_x_test[:100]
A_dataset_x_test = file['A_dataset_x_test'][:]
A_dataset_x_test = A_dataset_x_test[:100]
H_dataset_x_test = file['H_dataset_x_test'][:]
H_dataset_x_test = H_dataset_x_test[:100]
M_dataset_x_test = file['M_dataset_x_test'][:]
M_dataset_x_test = M_dataset_x_test[:100]
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,A_dataset_x_test,H_dataset_x_test,M_dataset_x_test))
pred_res = []
for image in x_test:
    image = image.astype('float32')
    image/=255
    image = np.expand_dims(image, axis=0)
    score = model.predict(image)
    if score[0][0] > 0.5:
      pred_res.append(1)
    else:
      pred_res.append(0)
truth = [0]*(100+100+100+100+100) + [1] *100 + [0]*(100)
counter = 0
for a,b in zip(pred_res,truth):
  if a == b:
    counter += 1
print('accuracy is %f' %(counter/len(truth)))
# Out:
# accuracy is 0.965714
