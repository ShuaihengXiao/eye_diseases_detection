# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144793 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import numpy as np
from keras.utils import np_utils
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout
import tqdm
import os
import cv2

# %%
file = h5py.File('/content/drive/My Drive/aug_dataset.hdf5',mode = 'r')

# %%
N_dataset_x_train = file['N_dataset_x_train'][:700]
N_dataset_y_train = file['N_dataset_y_train'][:700]
N_dataset_x_val = file['N_dataset_x_val'][:200]
N_dataset_y_val = file['N_dataset_y_val'][:200]
N_dataset_x_test = file['N_dataset_x_test'][:100]
N_dataset_y_test = file['N_dataset_y_test'][:100]

# %%
D_dataset_x_train = file['D_dataset_x_train'][:700]
D_dataset_y_train = file['D_dataset_y_train'][:700]
D_dataset_x_val = file['D_dataset_x_val'][:200]
D_dataset_y_val = file['D_dataset_y_val'][:200]
D_dataset_x_test = file['D_dataset_x_test'][:100]
D_dataset_y_test = file['D_dataset_y_test'][:100]

# %%
G_dataset_x_train = file['G_dataset_x_train'][:700]
G_dataset_y_train = file['G_dataset_y_train'][:700]
G_dataset_x_val = file['G_dataset_x_val'][:200]
G_dataset_y_val = file['G_dataset_y_val'][:200]
G_dataset_x_test = file['G_dataset_x_test'][:100]
G_dataset_y_test = file['G_dataset_y_test'][:100]

# %%
C_dataset_x_train = file['C_dataset_x_train'][:700]
C_dataset_y_train = file['C_dataset_y_train'][:700]
C_dataset_x_val = file['C_dataset_x_val'][:200]
C_dataset_y_val = file['C_dataset_y_val'][:200]
C_dataset_x_test = file['C_dataset_x_test'][:100]
C_dataset_y_test = file['C_dataset_y_test'][:100]

# %%
H_dataset_x_train = file['H_dataset_x_train'][:700]
H_dataset_y_train = file['H_dataset_y_train'][:700]
H_dataset_x_val = file['H_dataset_x_val'][:200]
H_dataset_y_val = file['H_dataset_y_val'][:200]
H_dataset_x_test = file['H_dataset_x_test'][:100]
H_dataset_y_test = file['H_dataset_y_test'][:100]

# %%
M_dataset_x_train = file['M_dataset_x_train'][:700]
M_dataset_y_train = file['M_dataset_y_train'][:700]
M_dataset_x_val = file['M_dataset_x_val'][:200]
M_dataset_y_val = file['M_dataset_y_val'][:200]
M_dataset_x_test = file['M_dataset_x_test'][:100]
M_dataset_y_test = file['M_dataset_y_test'][:100]

# %%
A_dataset_x_train = file['A_dataset_x_train'][:]
A_dataset_y_train = file['A_dataset_y_train'][:]
A_dataset_x_val = file['A_dataset_x_val'][:]
A_dataset_y_val = file['A_dataset_y_val'][:]
A_dataset_x_test = file['A_dataset_x_test'][:]
A_dataset_y_test = file['A_dataset_y_test'][:]

# %%
for i in range(len(A_dataset_y_train)):
    A_dataset_y_train[i] = 1
for i in range(len(A_dataset_y_val)):
    A_dataset_y_val[i] = 1
for i in range(len(A_dataset_y_test)):
    A_dataset_y_test[i] = 1

for i in range(len(N_dataset_y_train)):
    N_dataset_y_train[i] = 0
for i in range(len(N_dataset_y_val)):
    N_dataset_y_val[i] = 0
for i in range(len(N_dataset_y_test)):
    N_dataset_y_test[i] = 0

for i in range(len(D_dataset_y_train)):
    D_dataset_y_train[i] = 0
for i in range(len(D_dataset_y_val)):
    D_dataset_y_val[i] = 0
for i in range(len(D_dataset_y_test)):
    D_dataset_y_test[i] = 0

for i in range(len(G_dataset_y_train)):
    G_dataset_y_train[i] = 0
for i in range(len(G_dataset_y_val)):
    G_dataset_y_val[i] = 0
for i in range(len(G_dataset_y_test)):
    G_dataset_y_test[i] = 0

for i in range(len(C_dataset_y_train)):
    C_dataset_y_train[i] = 0
for i in range(len(C_dataset_y_val)):
    C_dataset_y_val[i] = 0
for i in range(len(C_dataset_y_test)):
    C_dataset_y_test[i] = 0

for i in range(len(H_dataset_y_train)):
    H_dataset_y_train[i] = 0
for i in range(len(H_dataset_y_val)):
    H_dataset_y_val[i] = 0
for i in range(len(H_dataset_y_test)):
    H_dataset_y_test[i] = 0

for i in range(len(M_dataset_y_train)):
    M_dataset_y_train[i] = 0
for i in range(len(M_dataset_y_val)):
    M_dataset_y_val[i] = 0
for i in range(len(M_dataset_y_test)):
    M_dataset_y_test[i] = 0

# %%
y_train = np.concatenate(( N_dataset_y_train,D_dataset_y_train,G_dataset_y_train,C_dataset_y_train,H_dataset_y_train,M_dataset_y_train,A_dataset_y_train))
y_val = np.concatenate((N_dataset_y_val,D_dataset_y_val,G_dataset_y_val,C_dataset_y_val,H_dataset_y_val,M_dataset_y_val,A_dataset_y_val))
y_test = np.concatenate((N_dataset_y_test,D_dataset_y_test,G_dataset_y_test,C_dataset_y_test,H_dataset_y_test,M_dataset_y_test,A_dataset_y_test))

# %%
x_train = np.concatenate(( N_dataset_x_train,D_dataset_x_train,G_dataset_x_train,C_dataset_x_train,H_dataset_x_train,M_dataset_x_train,A_dataset_x_train))
x_val = np.concatenate((N_dataset_x_val,D_dataset_x_val,G_dataset_x_val,C_dataset_x_val,H_dataset_x_val,M_dataset_x_val,A_dataset_x_val))
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,H_dataset_x_test,M_dataset_x_test,A_dataset_x_test))

# %%
del N_dataset_x_train
del N_dataset_y_train
del N_dataset_x_val
del N_dataset_y_val
del N_dataset_x_test
del N_dataset_y_test
del A_dataset_x_train
del A_dataset_y_train
del A_dataset_x_val
del A_dataset_y_val
del A_dataset_x_test
del A_dataset_y_test
del D_dataset_x_train
del D_dataset_y_train
del D_dataset_x_val
del D_dataset_y_val
del D_dataset_x_test
del D_dataset_y_test
del G_dataset_x_train
del G_dataset_y_train
del G_dataset_x_val
del G_dataset_y_val
del G_dataset_x_test
del G_dataset_y_test
del C_dataset_x_train
del C_dataset_y_train
del C_dataset_x_val
del C_dataset_y_val
del C_dataset_x_test
del C_dataset_y_test
del H_dataset_x_train
del H_dataset_y_train
del H_dataset_x_val
del H_dataset_y_val
del H_dataset_x_test
del H_dataset_y_test
del M_dataset_x_train
del M_dataset_y_train
del M_dataset_x_val
del M_dataset_y_val
del M_dataset_x_test
del M_dataset_y_test

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')


x_train/=255
x_val/=255
x_test /= 255

# %%
vgg = VGG19(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpoint = ModelCheckpoint("/content/drive/My Drive/weights_weights_NA.h5",monitor="val_accuracy",verbose=1,save_best_only=True,
                             save_weights_only=True)
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,verbose=1)

# %%
history = model.fit(x_train,y_train, batch_size = 32, epochs = 50, validation_data=(x_val,y_val),shuffle = True,verbose=1,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/50
# 176/176 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.7916
# Epoch 00001: val_accuracy improved from -inf to 0.81145, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 34s 190ms/step - loss: 0.4635 - accuracy: 0.7916 - val_loss: 0.4097 - val_accuracy: 0.8115
# Epoch 2/50
# 176/176 [==============================] - ETA: 0s - loss: 0.3028 - accuracy: 0.8714
# Epoch 00002: val_accuracy improved from 0.81145 to 0.89254, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 32s 180ms/step - loss: 0.3028 - accuracy: 0.8714 - val_loss: 0.2836 - val_accuracy: 0.8925
# Epoch 3/50
# 176/176 [==============================] - ETA: 0s - loss: 0.2402 - accuracy: 0.9075
# Epoch 00003: val_accuracy improved from 0.89254 to 0.89447, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 32s 184ms/step - loss: 0.2402 - accuracy: 0.9075 - val_loss: 0.2726 - val_accuracy: 0.8945
# Epoch 4/50
# 176/176 [==============================] - ETA: 0s - loss: 0.2048 - accuracy: 0.9236
# Epoch 00004: val_accuracy did not improve from 0.89447
# 176/176 [==============================] - 32s 183ms/step - loss: 0.2048 - accuracy: 0.9236 - val_loss: 0.3535 - val_accuracy: 0.8571
# Epoch 5/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9300
# Epoch 00005: val_accuracy did not improve from 0.89447
# 176/176 [==============================] - 33s 187ms/step - loss: 0.1886 - accuracy: 0.9300 - val_loss: 0.3064 - val_accuracy: 0.8662
# Epoch 6/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9433
# Epoch 00006: val_accuracy did not improve from 0.89447
# 176/176 [==============================] - 34s 192ms/step - loss: 0.1633 - accuracy: 0.9433 - val_loss: 0.4901 - val_accuracy: 0.7664
# Epoch 7/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9542
# Epoch 00007: val_accuracy improved from 0.89447 to 0.92600, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 35s 200ms/step - loss: 0.1420 - accuracy: 0.9542 - val_loss: 0.2151 - val_accuracy: 0.9260
# Epoch 8/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1247 - accuracy: 0.9640
# Epoch 00008: val_accuracy did not improve from 0.92600
# 176/176 [==============================] - 35s 200ms/step - loss: 0.1247 - accuracy: 0.9640 - val_loss: 0.2307 - val_accuracy: 0.9048
# Epoch 9/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1122 - accuracy: 0.9697
# Epoch 00009: val_accuracy did not improve from 0.92600
# 176/176 [==============================] - 35s 201ms/step - loss: 0.1122 - accuracy: 0.9697 - val_loss: 0.2035 - val_accuracy: 0.9215
# Epoch 10/50
# 176/176 [==============================] - ETA: 0s - loss: 0.1025 - accuracy: 0.9727
# Epoch 00010: val_accuracy improved from 0.92600 to 0.92664, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 36s 206ms/step - loss: 0.1025 - accuracy: 0.9727 - val_loss: 0.2019 - val_accuracy: 0.9266
# Epoch 11/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9804
# Epoch 00011: val_accuracy improved from 0.92664 to 0.92857, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 36s 205ms/step - loss: 0.0881 - accuracy: 0.9804 - val_loss: 0.1903 - val_accuracy: 0.9286
# Epoch 12/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9834
# Epoch 00012: val_accuracy improved from 0.92857 to 0.93050, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 38s 215ms/step - loss: 0.0801 - accuracy: 0.9834 - val_loss: 0.1925 - val_accuracy: 0.9305
# Epoch 13/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9754
# Epoch 00013: val_accuracy improved from 0.93050 to 0.93758, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0884 - accuracy: 0.9754 - val_loss: 0.1878 - val_accuracy: 0.9376
# Epoch 14/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0679 - accuracy: 0.9859
# Epoch 00014: val_accuracy improved from 0.93758 to 0.94466, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 212ms/step - loss: 0.0679 - accuracy: 0.9859 - val_loss: 0.1750 - val_accuracy: 0.9447
# Epoch 15/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0613 - accuracy: 0.9888
# Epoch 00015: val_accuracy improved from 0.94466 to 0.94852, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0613 - accuracy: 0.9888 - val_loss: 0.1684 - val_accuracy: 0.9485
# Epoch 16/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9909
# Epoch 00016: val_accuracy did not improve from 0.94852
# 176/176 [==============================] - 36s 206ms/step - loss: 0.0570 - accuracy: 0.9909 - val_loss: 0.1921 - val_accuracy: 0.9324
# Epoch 17/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9941
# Epoch 00017: val_accuracy did not improve from 0.94852
# 176/176 [==============================] - 37s 207ms/step - loss: 0.0494 - accuracy: 0.9941 - val_loss: 0.1866 - val_accuracy: 0.9331
# Epoch 18/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0460 - accuracy: 0.9948
# Epoch 00018: val_accuracy improved from 0.94852 to 0.95109, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0460 - accuracy: 0.9948 - val_loss: 0.1658 - val_accuracy: 0.9511
# Epoch 19/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0417 - accuracy: 0.9950
# Epoch 00019: val_accuracy improved from 0.95109 to 0.95238, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0417 - accuracy: 0.9950 - val_loss: 0.1629 - val_accuracy: 0.9524
# Epoch 20/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0412 - accuracy: 0.9955
# Epoch 00020: val_accuracy did not improve from 0.95238
# 176/176 [==============================] - 36s 206ms/step - loss: 0.0412 - accuracy: 0.9955 - val_loss: 0.1669 - val_accuracy: 0.9492
# Epoch 21/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0364 - accuracy: 0.9966
# Epoch 00021: val_accuracy did not improve from 0.95238
# 176/176 [==============================] - 36s 207ms/step - loss: 0.0364 - accuracy: 0.9966 - val_loss: 0.1756 - val_accuracy: 0.9376
# Epoch 22/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9984
# Epoch 00022: val_accuracy improved from 0.95238 to 0.95560, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 212ms/step - loss: 0.0309 - accuracy: 0.9984 - val_loss: 0.1610 - val_accuracy: 0.9556
# Epoch 23/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0297 - accuracy: 0.9980
# Epoch 00023: val_accuracy did not improve from 0.95560
# 176/176 [==============================] - 36s 207ms/step - loss: 0.0297 - accuracy: 0.9980 - val_loss: 0.1714 - val_accuracy: 0.9466
# Epoch 24/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9982
# Epoch 00024: val_accuracy did not improve from 0.95560
# 176/176 [==============================] - 36s 207ms/step - loss: 0.0293 - accuracy: 0.9982 - val_loss: 0.1630 - val_accuracy: 0.9517
# Epoch 25/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9977
# Epoch 00025: val_accuracy did not improve from 0.95560
# 176/176 [==============================] - 36s 206ms/step - loss: 0.0281 - accuracy: 0.9977 - val_loss: 0.1627 - val_accuracy: 0.9537
# Epoch 26/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9995
# Epoch 00026: val_accuracy improved from 0.95560 to 0.95624, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0235 - accuracy: 0.9995 - val_loss: 0.1592 - val_accuracy: 0.9562
# Epoch 27/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9998
# Epoch 00027: val_accuracy improved from 0.95624 to 0.95689, saving model to /content/drive/My Drive/weights_weights_NA.h5
# 176/176 [==============================] - 37s 210ms/step - loss: 0.0206 - accuracy: 0.9998 - val_loss: 0.1602 - val_accuracy: 0.9569
# Epoch 28/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9991
# Epoch 00028: val_accuracy did not improve from 0.95689
# 176/176 [==============================] - 36s 207ms/step - loss: 0.0207 - accuracy: 0.9991 - val_loss: 0.1631 - val_accuracy: 0.9569
# Epoch 29/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9996
# Epoch 00029: val_accuracy did not improve from 0.95689
# 176/176 [==============================] - 36s 206ms/step - loss: 0.0182 - accuracy: 0.9996 - val_loss: 0.1665 - val_accuracy: 0.9537
# Epoch 30/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0162 - accuracy: 0.9998
# Epoch 00030: val_accuracy did not improve from 0.95689
# 176/176 [==============================] - 36s 205ms/step - loss: 0.0162 - accuracy: 0.9998 - val_loss: 0.1794 - val_accuracy: 0.9395
# Epoch 31/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9998
# Epoch 00031: val_accuracy did not improve from 0.95689
# 176/176 [==============================] - 36s 206ms/step - loss: 0.0148 - accuracy: 0.9998 - val_loss: 0.1843 - val_accuracy: 0.9363
# Epoch 32/50
# 176/176 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9991
# Epoch 00032: val_accuracy did not improve from 0.95689
# 176/176 [==============================] - 36s 205ms/step - loss: 0.0182 - accuracy: 0.9991 - val_loss: 0.1831 - val_accuracy: 0.9402
# Epoch 00032: early stopping

# %%
model.evaluate(x_test,y_test)
# Out:
# 25/25 [==============================] - 5s 206ms/step - loss: 0.1628 - accuracy: 0.9498
# [0.16280899941921234, 0.9498118162155151]

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
fig = plt.figure(figsize=(12,6))
epochs = range(1,len(history.history['accuracy'])+1)
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"go-")
plt.plot(epochs,history.history["val_accuracy"],"ro-")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train","val"],loc = "upper left")

plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"go-")
plt.plot(epochs,history.history["val_loss"],"ro-")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train","val"],loc = "upper left")
plt.show()

# %%
import tensorflow as tf
tf.keras.utils.plot_model(model,show_shapes = True)

# %%
model.load_weights('/content/drive/My Drive/weights_weights_NA.h5')

# %%
N_dataset_x_test = file['N_dataset_x_test'][:]
N_dataset_x_test = N_dataset_x_test[:100]
D_dataset_x_test = file['D_dataset_x_test'][:]
D_dataset_x_test = D_dataset_x_test[:100]
G_dataset_x_test = file['G_dataset_x_test'][:]
G_dataset_x_test = G_dataset_x_test[:100]
C_dataset_x_test = file['C_dataset_x_test'][:]
C_dataset_x_test = C_dataset_x_test[:100]
A_dataset_x_test = file['A_dataset_x_test'][:]
A_dataset_x_test = A_dataset_x_test[:100]
H_dataset_x_test = file['H_dataset_x_test'][:]
H_dataset_x_test = H_dataset_x_test[:100]
M_dataset_x_test = file['M_dataset_x_test'][:]
M_dataset_x_test = M_dataset_x_test[:100]
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,A_dataset_x_test,H_dataset_x_test,M_dataset_x_test))
pred_res = []
for image in x_test:
    image = image.astype('float32')
    image/=255
    image = np.expand_dims(image, axis=0)
    score = model.predict(image)
    if score[0][0] > 0.5:
      pred_res.append(1)
    else:
      pred_res.append(0)
truth = [0]*(100+100+100+100) + [1] *100 + [0]*(100+100)
counter = 0
for a,b in zip(pred_res,truth):
  if a == b:
    counter += 1
print('accuracy is %f' %(counter/len(truth)))
# Out:
# accuracy is 0.958571
