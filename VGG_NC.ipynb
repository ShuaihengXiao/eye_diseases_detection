# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Selecting previously unselected package google-drive-ocamlfuse.
# (Reading database ... 144793 files and directories currently installed.)
# Preparing to unpack .../google-drive-ocamlfuse_0.7.23-0ubuntu1~ubuntu18.04.1_amd64.deb ...
# Unpacking google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Setting up google-drive-ocamlfuse (0.7.23-0ubuntu1~ubuntu18.04.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
import numpy as np

# %%
file = h5py.File('/content/drive/My Drive/aug_dataset.hdf5',mode = 'r')

# %%
N_dataset_x_train = file['N_dataset_x_train'][:700]
N_dataset_y_train = file['N_dataset_y_train'][:700]
N_dataset_x_val = file['N_dataset_x_val'][:200]
N_dataset_y_val = file['N_dataset_y_val'][:200]
N_dataset_x_test = file['N_dataset_x_test'][:100]
N_dataset_y_test = file['N_dataset_y_test'][:100]

# %%
D_dataset_x_train = file['D_dataset_x_train'][:700]
D_dataset_y_train = file['D_dataset_y_train'][:700]
D_dataset_x_val = file['D_dataset_x_val'][:200]
D_dataset_y_val = file['D_dataset_y_val'][:200]
D_dataset_x_test = file['D_dataset_x_test'][:100]
D_dataset_y_test = file['D_dataset_y_test'][:100]

# %%
G_dataset_x_train = file['G_dataset_x_train'][:700]
G_dataset_y_train = file['G_dataset_y_train'][:700]
G_dataset_x_val = file['G_dataset_x_val'][:200]
G_dataset_y_val = file['G_dataset_y_val'][:200]
G_dataset_x_test = file['G_dataset_x_test'][:100]
G_dataset_y_test = file['G_dataset_y_test'][:100]

# %%
A_dataset_x_train = file['A_dataset_x_train'][:700]
A_dataset_y_train = file['A_dataset_y_train'][:700]
A_dataset_x_val = file['A_dataset_x_val'][:200]
A_dataset_y_val = file['A_dataset_y_val'][:200]
A_dataset_x_test = file['A_dataset_x_test'][:100]
A_dataset_y_test = file['A_dataset_y_test'][:100]

# %%
H_dataset_x_train = file['H_dataset_x_train'][:700]
H_dataset_y_train = file['H_dataset_y_train'][:700]
H_dataset_x_val = file['H_dataset_x_val'][:200]
H_dataset_y_val = file['H_dataset_y_val'][:200]
H_dataset_x_test = file['H_dataset_x_test'][:100]
H_dataset_y_test = file['H_dataset_y_test'][:100]

# %%
M_dataset_x_train = file['M_dataset_x_train'][:700]
M_dataset_y_train = file['M_dataset_y_train'][:700]
M_dataset_x_val = file['M_dataset_x_val'][:200]
M_dataset_y_val = file['M_dataset_y_val'][:200]
M_dataset_x_test = file['M_dataset_x_test'][:100]
M_dataset_y_test = file['M_dataset_y_test'][:100]

# %%
C_dataset_x_train = file['C_dataset_x_train'][:]
C_dataset_y_train = file['C_dataset_y_train'][:]

# %%
C_dataset_x_val = file['C_dataset_x_val'][:]
C_dataset_y_val = file['C_dataset_y_val'][:]

# %%
C_dataset_x_test = file['C_dataset_x_test'][:]
C_dataset_y_test = file['C_dataset_y_test'][:]

# %%
for i in range(len(C_dataset_y_train)):
  C_dataset_y_train[i] = 1
for i in range(len(C_dataset_y_val)):
  C_dataset_y_val[i] = 1
for i in range(len(C_dataset_y_test)):
  C_dataset_y_test[i] = 1

for i in range(len(N_dataset_y_train)):
    N_dataset_y_train[i] = 0
for i in range(len(N_dataset_y_val)):
    N_dataset_y_val[i] = 0
for i in range(len(N_dataset_y_test)):
    N_dataset_y_test[i] = 0

for i in range(len(D_dataset_y_train)):
    D_dataset_y_train[i] = 0
for i in range(len(D_dataset_y_val)):
    D_dataset_y_val[i] = 0
for i in range(len(D_dataset_y_test)):
    D_dataset_y_test[i] = 0

for i in range(len(G_dataset_y_train)):
    G_dataset_y_train[i] = 0
for i in range(len(G_dataset_y_val)):
    G_dataset_y_val[i] = 0
for i in range(len(G_dataset_y_test)):
    G_dataset_y_test[i] = 0
for i in range(len(A_dataset_y_train)):
    A_dataset_y_train[i] = 0
for i in range(len(A_dataset_y_val)):
    A_dataset_y_val[i] = 0
for i in range(len(A_dataset_y_test)):
    A_dataset_y_test[i] = 0
for i in range(len(H_dataset_y_train)):
    H_dataset_y_train[i] = 0
for i in range(len(H_dataset_y_val)):
    H_dataset_y_val[i] = 0
for i in range(len(H_dataset_y_test)):
    H_dataset_y_test[i] = 0

for i in range(len(M_dataset_y_train)):
    M_dataset_y_train[i] = 0
for i in range(len(M_dataset_y_val)):
    M_dataset_y_val[i] = 0
for i in range(len(M_dataset_y_test)):
    M_dataset_y_test[i] = 0

# %%
y_train = np.concatenate(( N_dataset_y_train,D_dataset_y_train,G_dataset_y_train,C_dataset_y_train,H_dataset_y_train,M_dataset_y_train,A_dataset_y_train))
y_val = np.concatenate((N_dataset_y_val,D_dataset_y_val,G_dataset_y_val,C_dataset_y_val,H_dataset_y_val,M_dataset_y_val,A_dataset_y_val))
y_test = np.concatenate((N_dataset_y_test,D_dataset_y_test,G_dataset_y_test,C_dataset_y_test,H_dataset_y_test,M_dataset_y_test,A_dataset_y_test))

# %%
x_train = np.concatenate(( N_dataset_x_train,D_dataset_x_train,G_dataset_x_train,C_dataset_x_train,H_dataset_x_train,M_dataset_x_train,A_dataset_x_train))
x_val = np.concatenate((N_dataset_x_val,D_dataset_x_val,G_dataset_x_val,C_dataset_x_val,H_dataset_x_val,M_dataset_x_val,A_dataset_x_val))
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,H_dataset_x_test,M_dataset_x_test,A_dataset_x_test))

# %%
del N_dataset_x_train
del N_dataset_y_train
del N_dataset_x_val
del N_dataset_y_val
del N_dataset_x_test
del N_dataset_y_test
del A_dataset_x_train
del A_dataset_y_train
del A_dataset_x_val
del A_dataset_y_val
del A_dataset_x_test
del A_dataset_y_test
del D_dataset_x_train
del D_dataset_y_train
del D_dataset_x_val
del D_dataset_y_val
del D_dataset_x_test
del D_dataset_y_test
del G_dataset_x_train
del G_dataset_y_train
del G_dataset_x_val
del G_dataset_y_val
del G_dataset_x_test
del G_dataset_y_test
del C_dataset_x_train
del C_dataset_y_train
del C_dataset_x_val
del C_dataset_y_val
del C_dataset_x_test
del C_dataset_y_test
del H_dataset_x_train
del H_dataset_y_train
del H_dataset_x_val
del H_dataset_y_val
del H_dataset_x_test
del H_dataset_y_test
del M_dataset_x_train
del M_dataset_y_train
del M_dataset_x_val
del M_dataset_y_val
del M_dataset_x_test
del M_dataset_y_test

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')


x_train/=255
x_val/=255
x_test /= 255

# %%
from tensorflow.keras.applications.vgg19 import VGG19

# %%
vgg = VGG19(weights = 'imagenet', include_top = False, input_shape = (224, 224, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step

# %%
for layer in vgg.layers:
    layer.trainable = False

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten, Dense
model = Sequential()
model.add(vgg)
model.add(Flatten())
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint,EarlyStopping
checkpoint = ModelCheckpoint("/content/drive/My Drive/weights_weights_NC.h5",monitor="val_accuracy",verbose=1,save_best_only=True,
                             save_weights_only=True )
earlystop = EarlyStopping(monitor="val_accuracy",patience=5,verbose=1)

# %%
history = model.fit(x_train,y_train, batch_size = 32, epochs = 50,validation_data=(x_val,y_val),shuffle = True,verbose=1,callbacks=[checkpoint,earlystop])
# Out:
# Epoch 1/50
# 182/182 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9020
# Epoch 00001: val_accuracy improved from -inf to 0.92897, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 36s 198ms/step - loss: 0.2706 - accuracy: 0.9020 - val_loss: 0.1828 - val_accuracy: 0.9290
# Epoch 2/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9325
# Epoch 00002: val_accuracy improved from 0.92897 to 0.94579, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 36s 196ms/step - loss: 0.1898 - accuracy: 0.9325 - val_loss: 0.1653 - val_accuracy: 0.9458
# Epoch 3/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9450
# Epoch 00003: val_accuracy did not improve from 0.94579
# 182/182 [==============================] - 37s 201ms/step - loss: 0.1538 - accuracy: 0.9450 - val_loss: 0.2678 - val_accuracy: 0.9009
# Epoch 4/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9586
# Epoch 00004: val_accuracy did not improve from 0.94579
# 182/182 [==============================] - 35s 193ms/step - loss: 0.1163 - accuracy: 0.9586 - val_loss: 0.1866 - val_accuracy: 0.9433
# Epoch 5/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9632
# Epoch 00005: val_accuracy improved from 0.94579 to 0.95265, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 201ms/step - loss: 0.1079 - accuracy: 0.9632 - val_loss: 0.1271 - val_accuracy: 0.9526
# Epoch 6/50
# 130/182 [====================>.........] - ETA: 8s - loss: 0.1090 - accuracy: 0.9589Epoch 1/50
# 182/182 [==============================] - ETA: 0s - loss: 0.2706 - accuracy: 0.9020
# Epoch 00001: val_accuracy improved from -inf to 0.92897, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 36s 198ms/step - loss: 0.2706 - accuracy: 0.9020 - val_loss: 0.1828 - val_accuracy: 0.9290
# Epoch 2/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1898 - accuracy: 0.9325
# Epoch 00002: val_accuracy improved from 0.92897 to 0.94579, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 36s 196ms/step - loss: 0.1898 - accuracy: 0.9325 - val_loss: 0.1653 - val_accuracy: 0.9458
# Epoch 3/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9450
# Epoch 00003: val_accuracy did not improve from 0.94579
# 182/182 [==============================] - 37s 201ms/step - loss: 0.1538 - accuracy: 0.9450 - val_loss: 0.2678 - val_accuracy: 0.9009
# Epoch 4/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1163 - accuracy: 0.9586
# Epoch 00004: val_accuracy did not improve from 0.94579
# 182/182 [==============================] - 35s 193ms/step - loss: 0.1163 - accuracy: 0.9586 - val_loss: 0.1866 - val_accuracy: 0.9433
# Epoch 5/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1079 - accuracy: 0.9632
# Epoch 00005: val_accuracy improved from 0.94579 to 0.95265, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 201ms/step - loss: 0.1079 - accuracy: 0.9632 - val_loss: 0.1271 - val_accuracy: 0.9526
# Epoch 6/50
# 182/182 [==============================] - ETA: 0s - loss: 0.1032 - accuracy: 0.9627
# Epoch 00006: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 196ms/step - loss: 0.1032 - accuracy: 0.9627 - val_loss: 0.1305 - val_accuracy: 0.9483
#
# Epoch 00006: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 196ms/step - loss: 0.1032 - accuracy: 0.9627 - val_loss: 0.1305 - val_accuracy: 0.9483
# Epoch 7/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0644 - accuracy: 0.9688Epoch 7/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0823 - accuracy: 0.9723
# Epoch 00007: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 197ms/step - loss: 0.0823 - accuracy: 0.9723 - val_loss: 0.1608 - val_accuracy: 0.9377
#
# Epoch 00007: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 197ms/step - loss: 0.0823 - accuracy: 0.9723 - val_loss: 0.1608 - val_accuracy: 0.9377
# Epoch 8/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0111 - accuracy: 1.0000Epoch 8/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0604 - accuracy: 0.9820
# Epoch 00008: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0604 - accuracy: 0.9820 - val_loss: 0.1605 - val_accuracy: 0.9526
#
# Epoch 00008: val_accuracy did not improve from 0.95265
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0604 - accuracy: 0.9820 - val_loss: 0.1605 - val_accuracy: 0.9526
# Epoch 9/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0823 - accuracy: 0.9688Epoch 9/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9881
# Epoch 00009: val_accuracy improved from 0.95265 to 0.95763, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00009: val_accuracy improved from 0.95265 to 0.95763, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 205ms/step - loss: 0.0530 - accuracy: 0.9881 - val_loss: 0.1261 - val_accuracy: 0.9576
# 182/182 [==============================] - 37s 205ms/step - loss: 0.0530 - accuracy: 0.9881 - val_loss: 0.1261 - val_accuracy: 0.9576
# Epoch 10/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0823 - accuracy: 0.9688Epoch 10/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9862
# Epoch 00010: val_accuracy improved from 0.95763 to 0.96199, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00010: val_accuracy improved from 0.95763 to 0.96199, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0550 - accuracy: 0.9862 - val_loss: 0.1092 - val_accuracy: 0.9620
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0550 - accuracy: 0.9862 - val_loss: 0.1092 - val_accuracy: 0.9620
# Epoch 11/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0088 - accuracy: 1.0000Epoch 11/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0442 - accuracy: 0.9912
# Epoch 00011: val_accuracy improved from 0.96199 to 0.96511, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00011: val_accuracy improved from 0.96199 to 0.96511, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 203ms/step - loss: 0.0442 - accuracy: 0.9912 - val_loss: 0.1102 - val_accuracy: 0.9651
# 182/182 [==============================] - 37s 203ms/step - loss: 0.0442 - accuracy: 0.9912 - val_loss: 0.1102 - val_accuracy: 0.9651
# Epoch 12/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0378 - accuracy: 0.9688Epoch 12/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0402 - accuracy: 0.9911
# Epoch 00012: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 199ms/step - loss: 0.0402 - accuracy: 0.9911 - val_loss: 0.1762 - val_accuracy: 0.9333
#
# Epoch 00012: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 199ms/step - loss: 0.0402 - accuracy: 0.9911 - val_loss: 0.1762 - val_accuracy: 0.9333
# Epoch 13/50
#   1/182 [..............................] - ETA: 0s - loss: 0.1006 - accuracy: 0.9688Epoch 13/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0431 - accuracy: 0.9888
# Epoch 00013: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 199ms/step - loss: 0.0431 - accuracy: 0.9888 - val_loss: 0.1090 - val_accuracy: 0.9607
#
# Epoch 00013: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 199ms/step - loss: 0.0431 - accuracy: 0.9888 - val_loss: 0.1090 - val_accuracy: 0.9607
# Epoch 14/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000Epoch 14/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9924
# Epoch 00014: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0349 - accuracy: 0.9924 - val_loss: 0.1185 - val_accuracy: 0.9583
#
# Epoch 00014: val_accuracy did not improve from 0.96511
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0349 - accuracy: 0.9924 - val_loss: 0.1185 - val_accuracy: 0.9583
# Epoch 15/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0332 - accuracy: 1.0000Epoch 15/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0309 - accuracy: 0.9943
# Epoch 00015: val_accuracy improved from 0.96511 to 0.96698, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00015: val_accuracy improved from 0.96511 to 0.96698, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0309 - accuracy: 0.9943 - val_loss: 0.1025 - val_accuracy: 0.9670
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0309 - accuracy: 0.9943 - val_loss: 0.1025 - val_accuracy: 0.9670
# Epoch 16/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0171 - accuracy: 1.0000Epoch 16/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.9966
# Epoch 00016: val_accuracy improved from 0.96698 to 0.96822, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00016: val_accuracy improved from 0.96698 to 0.96822, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0248 - accuracy: 0.9966 - val_loss: 0.1025 - val_accuracy: 0.9682
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0248 - accuracy: 0.9966 - val_loss: 0.1025 - val_accuracy: 0.9682
# Epoch 17/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000Epoch 17/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9976
# Epoch 00017: val_accuracy did not improve from 0.96822
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0223 - accuracy: 0.9976 - val_loss: 0.1107 - val_accuracy: 0.9626
#
# Epoch 00017: val_accuracy did not improve from 0.96822
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0223 - accuracy: 0.9976 - val_loss: 0.1107 - val_accuracy: 0.9626
# Epoch 18/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0150 - accuracy: 1.0000Epoch 18/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0206 - accuracy: 0.9969
# Epoch 00018: val_accuracy did not improve from 0.96822
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0206 - accuracy: 0.9969 - val_loss: 0.1006 - val_accuracy: 0.9676
#
# Epoch 00018: val_accuracy did not improve from 0.96822
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0206 - accuracy: 0.9969 - val_loss: 0.1006 - val_accuracy: 0.9676
# Epoch 19/50
#   1/182 [..............................] - ETA: 0s - loss: 0.1085 - accuracy: 0.9688Epoch 19/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9974
# Epoch 00019: val_accuracy improved from 0.96822 to 0.97009, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00019: val_accuracy improved from 0.96822 to 0.97009, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0208 - accuracy: 0.9974 - val_loss: 0.0970 - val_accuracy: 0.9701
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0208 - accuracy: 0.9974 - val_loss: 0.0970 - val_accuracy: 0.9701
# Epoch 20/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0049 - accuracy: 1.0000Epoch 20/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0176 - accuracy: 0.9985
# Epoch 00020: val_accuracy improved from 0.97009 to 0.97072, saving model to /content/drive/My Drive/weights_weights_NC.h5
#
# Epoch 00020: val_accuracy improved from 0.97009 to 0.97072, saving model to /content/drive/My Drive/weights_weights_NC.h5
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0176 - accuracy: 0.9985 - val_loss: 0.0992 - val_accuracy: 0.9707
# 182/182 [==============================] - 37s 202ms/step - loss: 0.0176 - accuracy: 0.9985 - val_loss: 0.0992 - val_accuracy: 0.9707
# Epoch 21/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0154 - accuracy: 1.0000Epoch 21/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9974
# Epoch 00021: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0166 - accuracy: 0.9974 - val_loss: 0.1568 - val_accuracy: 0.9483
#
# Epoch 00021: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0166 - accuracy: 0.9974 - val_loss: 0.1568 - val_accuracy: 0.9483
# Epoch 22/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0242 - accuracy: 1.0000Epoch 22/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9978
# Epoch 00022: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0180 - accuracy: 0.9978 - val_loss: 0.1142 - val_accuracy: 0.9664
#
# Epoch 00022: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0180 - accuracy: 0.9978 - val_loss: 0.1142 - val_accuracy: 0.9664
# Epoch 23/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000Epoch 23/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9979
# Epoch 00023: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.1009 - val_accuracy: 0.9676
#
# Epoch 00023: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0147 - accuracy: 0.9979 - val_loss: 0.1009 - val_accuracy: 0.9676
# Epoch 24/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0096 - accuracy: 1.0000Epoch 24/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9985
# Epoch 00024: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0144 - accuracy: 0.9985 - val_loss: 0.1016 - val_accuracy: 0.9682
#
# Epoch 00024: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0144 - accuracy: 0.9985 - val_loss: 0.1016 - val_accuracy: 0.9682
# Epoch 25/50
#   1/182 [..............................] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000Epoch 25/50
# 182/182 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9991
# Epoch 00025: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0123 - accuracy: 0.9991 - val_loss: 0.1021 - val_accuracy: 0.9676
#
# Epoch 00025: val_accuracy did not improve from 0.97072
# 182/182 [==============================] - 36s 198ms/step - loss: 0.0123 - accuracy: 0.9991 - val_loss: 0.1021 - val_accuracy: 0.9676
# Epoch 00025: early stopping
# Epoch 00025: early stopping

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
fig = plt.figure(figsize=(12,6))
epochs = range(1,len(history.history['accuracy'])+1)
plt.subplot(1,2,1)
plt.plot(epochs,history.history["accuracy"],"go-")
plt.plot(epochs,history.history["val_accuracy"],"ro-")
plt.title("Model Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend(["Train","val"],loc = "upper left")

plt.subplot(1,2,2)
plt.plot(epochs,history.history["loss"],"go-")
plt.plot(epochs,history.history["val_loss"],"ro-")
plt.title("Model Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend(["Train","val"],loc = "upper left")
plt.show()

# %%
model.load_weights('/content/drive/My Drive/weights_weights_NC.h5')

# %%
model.evaluate(x_test,y_test)
# Out:
# 26/26 [==============================] - 5s 189ms/step - loss: 0.1010 - accuracy: 0.9733
# [0.1010114923119545, 0.9733333587646484]

# %%
N_dataset_x_test = file['N_dataset_x_test'][:]
N_dataset_x_test = N_dataset_x_test[:100]
D_dataset_x_test = file['D_dataset_x_test'][:]
D_dataset_x_test = D_dataset_x_test[:100]
G_dataset_x_test = file['G_dataset_x_test'][:]
G_dataset_x_test = G_dataset_x_test[:100]
C_dataset_x_test = file['C_dataset_x_test'][:]
C_dataset_x_test = C_dataset_x_test[:100]
A_dataset_x_test = file['A_dataset_x_test'][:]
A_dataset_x_test = A_dataset_x_test[:100]
H_dataset_x_test = file['H_dataset_x_test'][:]
H_dataset_x_test = H_dataset_x_test[:100]
M_dataset_x_test = file['M_dataset_x_test'][:]
M_dataset_x_test = M_dataset_x_test[:100]
x_test = np.concatenate((N_dataset_x_test,D_dataset_x_test,G_dataset_x_test,C_dataset_x_test,A_dataset_x_test,H_dataset_x_test,M_dataset_x_test))
pred_res = []
for image in x_test:
    image = image.astype('float32')
    image/=255
    image = np.expand_dims(image, axis=0)
    score = model.predict(image)
    if score[0][0] > 0.5:
      pred_res.append(1)
    else:
      pred_res.append(0)
truth = [0]*(100+100+100) + [1] *100 + [0]*(100+100+100)
counter = 0
for a,b in zip(pred_res,truth):
  if a == b:
    counter += 1
print('accuracy is %f' %(counter/len(truth)))
# Out:
# accuracy is 0.977143
